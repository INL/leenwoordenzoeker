# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
for root, dirs, files in os.walk("/content/gdrive/My Drive/Leenwoorden"):  
    for filename in files:
        print(filename)
# Out:
# leenwoord_data.tsv
# leenwoordenzoekertei.py
# leenwoordenzoekertei.cpython-36.pyc

# %%
#from '/content/gdrive/My Drive/Leenwoorden/leenwoordenzoekertei' import LoanWordStats
import importlib.util
spec = importlib.util.spec_from_file_location("leenwoorden", "/content/gdrive/My Drive/Leenwoorden/leenwoordenzoekertei.py")
leenwoorden = importlib.util.module_from_spec(spec)
spec.loader.exec_module(leenwoorden)

# %%
from IPython.core.display import display, HTML

# %%
def show(x):
    display(HTML(x.reportHTML()))
    
def do(x):
    lwFinder.find(x)
    show(lwFinder)

# %%
lwFinder = leenwoorden.LoanWordStats('/content/gdrive/My Drive/Leenwoorden/leenwoord_data.tsv')

# %%
do('zouden er leenwoorden actief zijn? meneer de doerak? Interessante parvenu.')
# Out:
#       <div>
#         <h3>Overzicht</h3>
#         <table>
#         <tr><td>Totaal aantal woorden<td> 10 </tr>
#         <tr><td>Totaal aantal unieke woorden<td> 10 </tr>
#         <tr><td>Totaal aantal leenwoorden<td> 5 (50.0%) </tr>
#         <tr><td>Totaal aantal unieke leenwoorden<td> 5  (50.0%) </tr>
#         </table>
#         <table>
#         <h3>Per taal<h3>
#          <tr><th>Taal</th><th>Woorden</th><th>Unieke woorden</th></tr>
#
#               <tr>
#                  <td>Frans
#                  <td> 3
#                  <td> 3
#               </tr>
#
#               <tr>
#                  <td>Duits
#                  <td> 1
#                  <td> 1
#               </tr>
#
#               <tr>
#                  <td>Russisch
#                  <td> 1
#                  <td> 1
#               </tr>
#
#         </table>
#         <h3>Alle unieke leenwoorden</h3>
#          <table>
#          <tr><th>Woord</th><th>Frequentie</th><th>Taal</th><th>Woordsoort</th></tr>
#
#               <tr>
#                  <td>actief
#                  <td> 1
#                  <td> Frans
#                  <td> bijvoeglijk naamwoord
#               </tr>
#
#               <tr>
#                  <td>doerak
#                  <td> 1
#                  <td> Russisch
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>interessant
#                  <td> 1
#                  <td> Frans
#                  <td> bijvoeglijk naamwoord
#               </tr>
#
#               <tr>
#                  <td>leenwoord
#                  <td> 1
#                  <td> Duits
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>parvenu
#                  <td> 1
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#         </table>
#       </div>

# %%
do('http://www.telegraaf.nl/')
# Out:
#       <div>
#         <h3>Overzicht</h3>
#         <table>
#         <tr><td>Totaal aantal woorden<td> 6044 </tr>
#         <tr><td>Totaal aantal unieke woorden<td> 2923 </tr>
#         <tr><td>Totaal aantal leenwoorden<td> 437 (7.2%) </tr>
#         <tr><td>Totaal aantal unieke leenwoorden<td> 108  (3.7%) </tr>
#         </table>
#         <table>
#         <h3>Per taal<h3>
#          <tr><th>Taal</th><th>Woorden</th><th>Unieke woorden</th></tr>
#
#               <tr>
#                  <td>Engels
#                  <td> 262
#                  <td> 33
#               </tr>
#
#               <tr>
#                  <td>Frans
#                  <td> 129
#                  <td> 56
#               </tr>
#
#               <tr>
#                  <td>Latijn
#                  <td> 36
#                  <td> 11
#               </tr>
#
#               <tr>
#                  <td>Duits
#                  <td> 10
#                  <td> 8
#               </tr>
#
#               <tr>
#                  <td>pseudo-Frans
#                  <td> 1
#                  <td> 1
#               </tr>
#
#         </table>
#         <h3>Alle unieke leenwoorden</h3>
#          <table>
#          <tr><th>Woord</th><th>Frequentie</th><th>Taal</th><th>Woordsoort</th></tr>
#
#               <tr>
#                  <td>airbag
#                  <td> 2
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>ambitieus
#                  <td> 2
#                  <td> Frans
#                  <td> bijvoeglijk naamwoord
#               </tr>
#
#               <tr>
#                  <td>appartement
#                  <td> 2
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>artikel
#                  <td> 3
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>bal
#                  <td> 1
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>balkon
#                  <td> 2
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>bar
#                  <td> 1
#                  <td> Duits
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>bek
#                  <td> 2
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>big bang
#                  <td> 1
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>bizar
#                  <td> 1
#                  <td> Frans
#                  <td> bijvoeglijk naamwoord
#               </tr>
#
#               <tr>
#                  <td>body
#                  <td> 2
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>bodyguard
#                  <td> 3
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>bouwen
#                  <td> 1
#                  <td> Duits
#                  <td> werkwoord
#               </tr>
#
#               <tr>
#                  <td>brand
#                  <td> 6
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>browser
#                  <td> 2
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>button
#                  <td> 1
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>buzzer
#                  <td> 2
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>cadeau
#                  <td> 1
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>center
#                  <td> 2
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>checken
#                  <td> 2
#                  <td> Engels
#                  <td> werkwoord
#               </tr>
#
#               <tr>
#                  <td>coffeeshop
#                  <td> 4
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>column
#                  <td> 6
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>contant
#                  <td> 1
#                  <td> Frans
#                  <td> bijvoeglijk naamwoord
#               </tr>
#
#               <tr>
#                  <td>data
#                  <td> 2
#                  <td> Latijn
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>date
#                  <td> 1
#                  <td> Engels
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>datum
#                  <td> 4
#                  <td> Latijn
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>defensie
#                  <td> 2
#                  <td> Latijn
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>element
#                  <td> 1
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>emotie
#                  <td> 2
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>enorm
#                  <td> 4
#                  <td> Frans
#                  <td> bijvoeglijk naamwoord
#               </tr>
#
#               <tr>
#                  <td>excuus
#                  <td> 4
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>exemplaar
#                  <td> 1
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>explosie
#                  <td> 2
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>fantastisch
#                  <td> 1
#                  <td> Frans
#                  <td> bijvoeglijk naamwoord
#               </tr>
#
#               <tr>
#                  <td>feit
#                  <td> 2
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>fijn
#                  <td> 4
#                  <td> Frans
#                  <td> bijvoeglijk naamwoord
#               </tr>
#
#               <tr>
#                  <td>fooi
#                  <td> 1
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>fotograferen
#                  <td> 1
#                  <td> pseudo-Frans
#                  <td> werkwoord
#               </tr>
#
#               <tr>
#                  <td>fout
#                  <td> 2
#                  <td> Frans
#                  <td> zelfstandig naamwoord
#               </tr>
#
#               <tr>
#                  <td>garage
